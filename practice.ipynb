# %%
l =[1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l =[1,2,3,4]
print(l[1])
# Out:
# 2

# %%
l =[1,2,3,4]
l[1]=13
print(l)
# Out:
# [1, 13, 3, 4]

# %%
l =[1,2,3,4]
l.append(14)
print(l)
# Out:
# [1, 2, 3, 4, 14]

# %%
l =[1,2,3,4]
l.append(14)
l.remove(2)
print(l)
# Out:
# [1, 3, 4, 14]

# %%
l =[1,2,3,4]
l.append(14)
l.remove(4)
print(l)
# Out:
# [1, 2, 3, 14]

# %%
l =[1,2,3,4]
l.pop(1)
print(l)
# Out:
# [1, 3, 4]

# %%
l =[1,2,3,4]
print(len(l))
# Out:
# 4

# %%
l =[1,2,3,4]
l[:2]
print(l[:2])
print(l)
# Out:
# [1, 2]
# [1, 2, 3, 4]

# %%
l =[1,2,3,4]
l.reverse()
print(l)
# Out:
# [4, 3, 2, 1]

# %%
l =[2,3,4,1]
l.sort()
print(l)
# Out:
# [1, 2, 3, 4]
